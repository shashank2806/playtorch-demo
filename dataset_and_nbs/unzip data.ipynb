# %%
# !unzip IMAGES
# Out:
# Archive:  IMAGES.zip
#    creating: IMAGES/car_front_left_view/
#   inflating: IMAGES/car_front_left_view/01d487e89802475b918feb64d408272a.jpeg
#   inflating: IMAGES/car_front_left_view/032dffd9354a46e0a3517c7a1c0046d6.jpeg
#   inflating: IMAGES/car_front_left_view/043d54f576a64eeaa38746968c2a9e12.jpeg
#   inflating: IMAGES/car_front_left_view/053aa1fd67534b56b8d7431f46ed4c27.jpeg
#   inflating: IMAGES/car_front_left_view/08c13509536940b89d5ed8c93f18d4fc.jpeg
#   inflating: IMAGES/car_front_left_view/0ebd489c39e048a7b29b9ac588eea344.jpeg
#   inflating: IMAGES/car_front_left_view/10956264e2a04eb09e493a44bc39cfd3.jpeg
#   inflating: IMAGES/car_front_left_view/1891e6b020b84040a61e06859ea1fd41.jpeg
#   inflating: IMAGES/car_front_left_view/18aafa1f98b946c983596a6795deb6b2.jpeg
#   inflating: IMAGES/car_front_left_view/196f3d5c102e4dddad8b24f06805ed3c.jpeg
#   inflating: IMAGES/car_front_left_view/21f85ac823f442c48dbd9f0c6d883217.jpeg
# ...

# %%
import os
import shutil

# %%
os.listdir('IMAGES')
# Out:
# ['car_front_left_view',
#  'car_front_right_view',
#  'car_front_view',
#  'train',
#  'val']

# %%
for folder in os.listdir('IMAGES')[:3]:
    images = os.listdir(f'IMAGES/{folder}')
    folder_name = folder
    os.mkdir(f'IMAGES/val/{folder}')
    for file in images[-7:]:
        shutil.move(f'IMAGES/{folder}/{file}', f'IMAGES/val/{folder}')
